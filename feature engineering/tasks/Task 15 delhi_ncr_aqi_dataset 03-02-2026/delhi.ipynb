# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\RABIN RESIN\\Desktop\\luminar\\development-journey\\mechine learning journey\\feature engineering\\tasks\\delhi_ncr_aqi_dataset.csv")
df.shape
# Out:
# (201664, 25)

# %%
df.isnull().sum()
# Out:
# datetime        0
# date            0
# year            0
# month           0
# day             0
# hour            0
# day_of_week     0
# is_weekend      0
# season          0
# city            0
# station         0
# latitude        0
# longitude       0
# pm25            0
# pm10            0
# no2             0
# so2             0
# co              0
# o3              0
# temperature     0
# humidity        0
# wind_speed      0
# visibility      0
# aqi             0
# aqi_category    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['datetime', 'date', 'year', 'month', 'day', 'hour', 'day_of_week',
#        'is_weekend', 'season', 'city', 'station', 'latitude', 'longitude',
#        'pm25', 'pm10', 'no2', 'so2', 'co', 'o3', 'temperature', 'humidity',
#        'wind_speed', 'visibility', 'aqi', 'aqi_category'],
#       dtype='object')

# %%
df.head()
# Out:
#               datetime        date  year  month  day  hour day_of_week  \
# 0  2020-01-01 06:00:00  2020-01-01  2020      1    1     6   Wednesday
# 1  2020-01-01 12:00:00  2020-01-01  2020      1    1    12   Wednesday
# 2  2020-01-01 18:00:00  2020-01-01  2020      1    1    18   Wednesday
# 3  2020-01-01 23:00:00  2020-01-01  2020      1    1    23   Wednesday
# 4  2020-01-01 06:00:00  2020-01-01  2020      1    1     6   Wednesday
#
#    is_weekend  season   city  ...    no2   so2    co    o3  temperature  \
# 0           0  winter  Delhi  ...  119.6  47.7  5.19  12.3          9.4
# 1           0  winter  Delhi  ...  117.9  39.3  4.32  15.8         20.6
# 2           0  winter  Delhi  ...  150.1  36.3  7.13  14.3         12.4
# 3           0  winter  Delhi  ...  142.0  30.3  4.90  13.2         14.4
# 4           0  winter  Delhi  ...  138.4  41.5  7.56  15.4          6.8
#
#    humidity  wind_speed  visibility  aqi  aqi_category
# ...

# %%
df["temperature"]=df["temperature"].astype("int")
df["city"]=df["city"].astype("str")

# %%
sns.barplot(data=df,x="city",y="temperature")
# Out:
# <Axes: xlabel='city', ylabel='temperature'>

# %%
sns.lineplot(data=df,x="city",y="temperature")
# Out:
# <Axes: xlabel='city', ylabel='temperature'>

# %%
sns.lineplot(data=df,x="temperature",y="humidity",hue="city")
# Out:
# <Axes: xlabel='temperature', ylabel='humidity'>

# %%
sns.boxplot(data=df,x="temperature",y="humidity")
# Out:
# <Axes: xlabel='temperature', ylabel='humidity'>

# %%
sns.scatterplot(data=df,y="temperature",x="season",hue="city")
# Out:
# <Axes: xlabel='season', ylabel='temperature'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201664 entries, 0 to 201663
# Data columns (total 25 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   datetime      201664 non-null  object
#  1   date          201664 non-null  object
#  2   year          201664 non-null  int64
#  3   month         201664 non-null  int64
#  4   day           201664 non-null  int64
#  5   hour          201664 non-null  int64
#  6   day_of_week   201664 non-null  object
#  7   is_weekend    201664 non-null  int64
#  8   season        201664 non-null  object
#  9   city          201664 non-null  object
#  10  station       201664 non-null  object
#  11  latitude      201664 non-null  float64
#  12  longitude     201664 non-null  float64
#  13  pm25          201664 non-null  float64
#  14  pm10          201664 non-null  float64
#  15  no2           201664 non-null  float64
#  16  so2           201664 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['datetime', 'date', 'year', 'month', 'day', 'hour', 'day_of_week',
#        'is_weekend', 'season', 'city', 'station', 'latitude', 'longitude',
#        'pm25', 'pm10', 'no2', 'so2', 'co', 'o3', 'temperature', 'humidity',
#        'wind_speed', 'visibility', 'aqi', 'aqi_category'],
#       dtype='object')

# %%
columns=["latitude","longitude","pm25","pm10","no2","so2","co","o3","temperature",'humidity','wind_speed', 'visibility', 'aqi']
df[columns].corr()
# Out:
#              latitude  longitude      pm25      pm10       no2       so2  \
# latitude     1.000000  -0.220539  0.040426  0.040217  0.039045  0.101809
# longitude   -0.220539   1.000000  0.005327  0.005402  0.004620 -0.000529
# pm25         0.040426   0.005327  1.000000  0.992215  0.962862  0.958414
# pm10         0.040217   0.005402  0.992215  1.000000  0.955457  0.951139
# no2          0.039045   0.004620  0.962862  0.955457  1.000000  0.923156
# so2          0.101809  -0.000529  0.958414  0.951139  0.923156  1.000000
# co           0.038691   0.005062  0.965594  0.958214  0.967640  0.925488
# o3          -0.016097  -0.002635 -0.362444 -0.359854 -0.355925 -0.357976
# temperature  0.000481  -0.000272 -0.517732 -0.513766 -0.491002 -0.488065
# humidity     0.000223   0.000098 -0.042363 -0.041826 -0.069282 -0.024170
# wind_speed   0.000120  -0.000068 -0.470176 -0.466600 -0.450599 -0.447238
# visibility  -0.042325  -0.005556 -0.672511 -0.667335 -0.648512 -0.627482
# ...

# %%
sns.heatmap(df[columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
value=["no2","so2","co","o3","aqi"]
sns.heatmap(df[value].corr(),annot= True)
# Out:
# <Axes: >
