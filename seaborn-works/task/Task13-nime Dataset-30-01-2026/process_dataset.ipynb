# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("C:\\Users\\RABIN RESIN\\Desktop\\luminar\\development-journey\\mechine learning journey\\seaborn-works\\task\\Task13-nime Dataset-30-01-2026\\anime.csv")
df.shape
# Out:
# (10000, 12)

# %%
df.isnull().sum()
# Out:
# anime_id       0
# title          0
# score          0
# rank           0
# popularity     0
# members        0
# synopsis       2
# start_date     2
# end_date      84
# type           0
# episodes      48
# image_url      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['anime_id', 'title', 'score', 'rank', 'popularity', 'members',
#        'synopsis', 'start_date', 'end_date', 'type', 'episodes', 'image_url'],
#       dtype='object')

# %%
df.head(25)
# Out:
#     anime_id                                              title  score  rank  \
# 0      28977                                           Gintama°   9.05     8
# 1      57555                       Chainsaw Man Movie: Reze-hen   9.18     2
# 2      11061                             Hunter x Hunter (2011)   9.03     9
# 3      52991                                  Sousou no Frieren   9.29     1
# 4       9969                                           Gintama'   9.02    11
# 5      15417                                Gintama': Enchousen   9.02    12
# 6      39486                                 Gintama: The Final   9.05     7
# 7      38524                 Shingeki no Kyojin Season 3 Part 2   9.05     6
# 8      34096                                           Gintama.   8.98    15
# 9      41467                          Bleach: Sennen Kessen-hen   8.99    14
# 10      5114                   Fullmetal Alchemist: Brotherhood   9.10     3
# ...
