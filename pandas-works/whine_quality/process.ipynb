# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("C:\\Users\\RABIN RESIN\\Desktop\\luminar\\development-journey\\mechine learning journey\\pandas-works\\whine_quality\\winequality-white.csv",delimiter=(";"))
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df["fixed acidity"]
# Out:
# 0       7.0
# 1       6.3
# 2       8.1
# 3       7.2
# 4       7.2
#        ...
# 4893    6.2
# 4894    6.6
# 4895    6.5
# 4896    5.5
# 4897    6.0
# Name: fixed acidity, Length: 4898, dtype: float64

# %%
df.shape
# Out:
# (4898, 12)

# %%
df[["alcohol","quality","volatile acidity"]].corr()
# Out:
#                    alcohol   quality  volatile acidity
# alcohol           1.000000  0.435575          0.067718
# quality           0.435575  1.000000         -0.194723
# volatile acidity  0.067718 -0.194723          1.000000
