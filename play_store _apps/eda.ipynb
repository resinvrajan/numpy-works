# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\RABIN RESIN\\Desktop\\luminar\\development-journey\\mechine learning journey\\play_store _apps\\cleaned_playstore.csv")
df.shape
# Out:
# (9659, 16)

# %%
df.isnull().sum()
# Out:
# Id                   0
# App                  0
# Category             0
# Rating            1463
# Reviews              0
# Size              1227
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Current Ver          8
# Android Ver          2
# year                 0
# month                0
# day                  0
# dtype: int64

# %%
df["Rating"].fillna(round(df["Rating"].mean(),1),inplace=True)
# Out:
# C:\Users\RABIN RESIN\AppData\Local\Temp\ipykernel_17000\3782230475.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Rating"].fillna(round(df["Rating"].mean(),1),inplace=True)

# %%
df["Size"].fillna(df["Size"].mode()[0],inplace=True)
# Out:
# C:\Users\RABIN RESIN\AppData\Local\Temp\ipykernel_17000\4092059901.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Size"].fillna(df["Size"].mode()[0],inplace=True)

# %%
df["Android Ver"].fillna("unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                0
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       8
# Android Ver       0
# year              0
# month             0
# day               0
# dtype: int64

# %%
df["Type"].fillna(df["Type"].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                0
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       8
# Android Ver       0
# year              0
# month             0
# day               0
# dtype: int64

# %%
df["Current Ver"].fillna("unknown",inplace=True)
# Out:
# C:\Users\RABIN RESIN\AppData\Local\Temp\ipykernel_17000\1049019101.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Current Ver"].fillna("unknown",inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                0
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Current Ver       0
# Android Ver       0
# year              0
# month             0
# day               0
# dtype: int64
